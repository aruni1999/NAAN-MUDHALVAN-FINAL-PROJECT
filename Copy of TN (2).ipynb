# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, LSTM, Conv1D, MaxPooling1D, Flatten

# Example data for classification/prediction task
# Replace this with your own dataset
X_train = np.random.random((1000, 10, 1))  # Example features (assuming a sequence of length 10 with 1 feature)
y_train = np.random.randint(2, size=(1000,))  # Example labels (binary classification)

# Convolutional Neural Network (CNN)
cnn_model = Sequential([
    Conv1D(32, 3, activation='relu', input_shape=(10, 1)),
    MaxPooling1D(2),
    Flatten(),
    Dense(32, activation='relu'),
    Dense(1, activation='sigmoid')
])

# Compile the CNN model
cnn_model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# Train the CNN model
cnn_model.fit(X_train, y_train, epochs=10, batch_size=32)
# Out:
# Epoch 1/10
# 32/32 [==============================] - 1s 4ms/step - loss: 0.6948 - accuracy: 0.4910
# Epoch 2/10
# 32/32 [==============================] - 0s 3ms/step - loss: 0.6952 - accuracy: 0.4810
# Epoch 3/10
# 32/32 [==============================] - 0s 3ms/step - loss: 0.6935 - accuracy: 0.5030
# Epoch 4/10
# 32/32 [==============================] - 0s 3ms/step - loss: 0.6927 - accuracy: 0.5120
# Epoch 5/10
# 32/32 [==============================] - 0s 3ms/step - loss: 0.6929 - accuracy: 0.5070
# Epoch 6/10
# 32/32 [==============================] - 0s 2ms/step - loss: 0.6942 - accuracy: 0.5070
# Epoch 7/10
# 32/32 [==============================] - 0s 3ms/step - loss: 0.6911 - accuracy: 0.5410
# Epoch 8/10
# 32/32 [==============================] - 0s 3ms/step - loss: 0.6908 - accuracy: 0.5210
# Epoch 9/10
# 32/32 [==============================] - 0s 3ms/step - loss: 0.6899 - accuracy: 0.5450
# Epoch 10/10
# 32/32 [==============================] - 0s 3ms/step - loss: 0.6904 - accuracy: 0.5360
